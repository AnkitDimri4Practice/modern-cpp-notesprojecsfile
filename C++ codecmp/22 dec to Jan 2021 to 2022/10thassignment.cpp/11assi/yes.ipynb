# %%
import numpy as np
arr1=int(input("Number of elements in the array:-"))
n=list(map(int, input("elements of array:-").strip().split()))
print(n)
arr2=int(input("Number of elements in the array:-"))
n1=list(map(int, input("elements of array:-").strip().split()))
print(n1)
   
print ("1st array : ", n)  
print ("2nd array : ", n1)  
   
out_arr = np.add(n, n1)  
print ("added array : ", out_arr)
# Out:
# [12, 3, 1]
# [1, 2, 4]
# 1st array :  [12, 3, 1]
# 2nd array :  [1, 2, 4]
# added array :  [13  5  5]
